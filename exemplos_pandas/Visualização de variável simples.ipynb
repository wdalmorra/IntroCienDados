# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('zap.csv',encoding='utf-8')

# %%
len(df)
# Out:
# 3481

# %%
df['preco_int'] = df.preco.apply(lambda x:int(x.replace(".","")))

# %%
df.groupby('bairro').count().preco.sort_values(ascending=False).head()
# Out:
# bairro
# Centro         1166
# Areal           606
# Três Vendas     599
# Fragata         355
# Laranjal        346
# Name: preco, dtype: int64

# %%
df.preco_int.describe()
# Out:
# count    3.481000e+03
# mean     4.332874e+05
# std      5.191312e+05
# min      9.500000e+01
# 25%      1.900000e+05
# 50%      2.900000e+05
# 75%      4.900000e+05
# max      1.144000e+07
# Name: preco_int, dtype: float64

# %%
import seaborn as sns

(df.preco_int/1000).plot(kind='hist',bins=200)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.kdeplot(df[(df.bairro=='Centro') & (df.preco_int<=1000000)].preco_int/1000,bw=20)
sns.kdeplot(df[(df.bairro== u'Areal') & (df.preco_int<=1000000)].preco_int/1000,bw=20)
plt.ylim(0,0.004)
plt.grid()

# %%
plt.boxplot([(df[(df.bairro=='Centro') & (df.preco_int<=1000000)].preco_int/1000),(df[(df.bairro=='Areal') & (df.preco_int<=1000000)].preco_int/1000)])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a296928d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a296a1850>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a296aeb50>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a296ae510>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a29692ad0>,
# ...
#   <matplotlib.lines.Line2D at 0x1a296b9e10>]}

# %%
(df[(df.bairro=='Centro') & (df.preco_int<=1000000)].preco_int/1000).describe()
# Out:
# count    1096.000000
# mean      383.912599
# std       213.140218
# min         0.573000
# 25%       222.900000
# 50%       320.000000
# 75%       480.000000
# max      1000.000000
# Name: preco_int, dtype: float64

# %%
(df[(df.bairro=='Areal') & (df.preco_int<=1000000)].preco_int/1000).describe()
# Out:
# count     577.000000
# mean      323.680508
# std       183.879074
# min        15.000000
# 25%       185.000000
# 50%       280.000000
# 75%       394.000000
# max      1000.000000
# Name: preco_int, dtype: float64
